# %% [markdown]
# # 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2. Git Clone into Drive

# %%
import os
from google.colab import userdata
path = "/content/drive" + userdata.get('PATH')
user_name = userdata.get('USER_NAME')
access_token = userdata.get('GITHUB_ACCESS_TOKEN')
repository_name = userdata.get('REPOSITORY_NAME')

os.chdir(path)
# !git clone https://{user_name}:{access_token}@github.com/{user_name}/{repository_name}.git
# Out:
# Cloning into 'study'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %% [markdown]
# # 3. Set Git Configure

# %%
os.chdir(f"{path}/{repository_name}")

# !git config --global user.name '{user_name}'
# !git config --global user.email '{user_email}'

# %% [markdown]
# # 4. Commit Current Notebook

# %%
import os
import glob

def get_file_name():

  notebook_files = glob.glob(f"{path}/{repository_name}/{directory_name}/*.ipynb")

  if notebook_files:
      notebook_files.sort(key=os.path.getmtime, reverse=True)
      notebook_name = notebook_files[0].split("/")[-1]
      return notebook_name
  else:
      return None

directory_name = '혼자_공부하는_머신러닝_딥러닝'
os.chdir(f"{path}/{repository_name}/{directory_name}")

file_name = get_file_name()
print(file_name)
# Out:
# 0.connect_github_with_colab.ipynb

# %%
commit_msg = f"update {file_name}"

# !git add {file_name}
# !git commit -m {commit_msg}
# !git push

# %% [markdown]
# ---

# %%
import os, glob
from google.colab import drive, userdata

def get_file_name(path, repository_name ,directory_name):
  notebook_files = glob.glob(f"{path}/{repository_name}/{directory_name}/*.ipynb")

  if notebook_files:
      notebook_files.sort(key=os.path.getmtime, reverse=True)
      notebook_name = notebook_files[0].split("/")[-1]
      print(f"최근 수정된 노트북 파일: {notebook_name}")
      return notebook_name
  else:
      return None

def set_github_config():
  user_name = userdata.get('USER_NAME')
  user_email = userdata.get('USER_EMAIL')
  # !git config --global user.name '{user_name}'
  # !git config --global user.email '{user_email}'
  # !git config --global core.quotepath false

def commit(file_path, commit_msg):
  # !git add .
  # !git commit -m '{commit_msg}'
  # !git push

drive.mount('/content/drive')

path = "/content/drive" + userdata.get('PATH')
repository_name = userdata.get('REPOSITORY_NAME')
os.chdir(f"{path}/{repository_name}")

directory_name = '혼자_공부하는_머신러닝_딥러닝'
file_name = get_file_name(path, repository_name, directory_name)
file_path = f'{directory_name}/{file_name}'
commit_msg = f"create {file_name}"

set_github_config()
commit(file_path, commit_msg)
# Out:
# Mounted at /content/drive
# [main 6e271d1] create None
#  6 files changed, 3 insertions(+), 2 deletions(-)
#  rename machine_learning/{0.connect_github_with_colab.ipynb => 00.connect_github_with_colab.ipynb} (100%)
#  create mode 100644 machine_learning/01.k-NeighborsClassifier.ipynb
#  create mode 100644 machine_learning/02.sampling_bias.ipynb
#  create mode 100644 machine_learning/03.Data_preprocessing.ipynb
#  delete mode 100644 machine_learning/1.k-NeighborsClassifier.ipynb
#  delete mode 100644 machine_learning/2.sampling_bias.ipynb
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 79.78 KiB | 2.42 MiB/s, done.
# Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/kyeong8139/study.git
#    b9679d4..6e271d1  main -> main
